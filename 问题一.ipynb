# %%
import pandas as pd

file1 = pd.read_excel('data/附件.xlsx',sheet_name='表单1')
file2 = pd.read_excel('data/附件.xlsx',sheet_name='表单2')
file3 = pd.read_excel('data/附件.xlsx',sheet_name='表单3')

# %% [markdown]
# # 1 问题一

# %%
file1
# Out:
#     文物编号 纹饰  类型   颜色 表面风化
# 0      1  C  高钾   蓝绿  无风化
# 1      2  A  铅钡   浅蓝   风化
# 2      3  A  高钾   蓝绿  无风化
# 3      4  A  高钾   蓝绿  无风化
# 4      5  A  高钾   蓝绿  无风化
# 5      6  A  高钾   蓝绿  无风化
# 6      7  B  高钾   蓝绿   风化
# 7      8  C  铅钡    紫   风化
# 8      9  B  高钾   蓝绿   风化
# 9     10  B  高钾   蓝绿   风化
# 10    11  C  铅钡   浅蓝   风化
# 11    12  B  高钾   蓝绿   风化
# 12    13  C  高钾   浅蓝  无风化
# 13    14  C  高钾   深绿  无风化
# 14    15  C  高钾   浅蓝  无风化
# 15    16  C  高钾   浅蓝  无风化
# 16    17  C  高钾   浅蓝  无风化
# 17    18  A  高钾   深蓝  无风化
# 18    19  A  铅钡  NaN   风化
# 19    20  A  铅钡   浅蓝  无风化
# 20    21  A  高钾   蓝绿  无风化
# 21    22  B  高钾   蓝绿   风化
# 22    23  A  铅钡   蓝绿   风化
# 23    24  C  铅钡    紫  无风化
# 24    25  C  铅钡   浅蓝   风化
# 25    26  C  铅钡    紫   风化
# 26    27  B  高钾   蓝绿   风化
# 27    28  A  铅钡   浅蓝   风化
# 28    29  A  铅钡   浅蓝   风化
# 29    30  A  铅钡   深蓝  无风化
# 30    31  C  铅钡    紫  无风化
# 31    32  C  铅钡   浅绿  无风化
# 32    33  C  铅钡   深绿  无风化
# 33    34  C  铅钡   深绿   风化
# 34    35  C  铅钡   浅绿  无风化
# 35    36  C  铅钡   深绿   风化
# 36    37  C  铅钡   深绿  无风化
# 37    38  C  铅钡   深绿   风化
# 38    39  C  铅钡   深绿   风化
# 39    40  C  铅钡  NaN   风化
# 40    41  C  铅钡   浅绿   风化
# 41    42  A  铅钡   浅蓝   风化
# 42    43  C  铅钡   浅蓝   风化
# 43    44  A  铅钡   浅蓝   风化
# 44    45  A  铅钡   浅蓝  无风化
# 45    46  A  铅钡   浅蓝  无风化
# 46    47  A  铅钡   浅蓝  无风化
# 47    48  A  铅钡  NaN   风化
# 48    49  A  铅钡    黑   风化
# 49    50  A  铅钡    黑   风化
# 50    51  C  铅钡   浅蓝   风化
# 51    52  C  铅钡   浅蓝   风化
# 52    53  A  铅钡   浅蓝   风化
# 53    54  C  铅钡   浅蓝   风化
# 54    55  C  铅钡    绿  无风化
# 55    56  C  铅钡   蓝绿   风化
# 56    57  C  铅钡   蓝绿   风化
# 57    58  C  铅钡  NaN   风化

# %%
weathering = file1[file1['表面风化'] =='风化']
no_weathering= file1[file1['表面风化'] =='无风化']
weathering
# Out:
#     文物编号 纹饰  类型   颜色 表面风化
# 1      2  A  铅钡   浅蓝   风化
# 6      7  B  高钾   蓝绿   风化
# 7      8  C  铅钡    紫   风化
# 8      9  B  高钾   蓝绿   风化
# 9     10  B  高钾   蓝绿   风化
# 10    11  C  铅钡   浅蓝   风化
# 11    12  B  高钾   蓝绿   风化
# 18    19  A  铅钡  NaN   风化
# 21    22  B  高钾   蓝绿   风化
# 22    23  A  铅钡   蓝绿   风化
# 24    25  C  铅钡   浅蓝   风化
# 25    26  C  铅钡    紫   风化
# 26    27  B  高钾   蓝绿   风化
# 27    28  A  铅钡   浅蓝   风化
# 28    29  A  铅钡   浅蓝   风化
# 33    34  C  铅钡   深绿   风化
# 35    36  C  铅钡   深绿   风化
# 37    38  C  铅钡   深绿   风化
# 38    39  C  铅钡   深绿   风化
# 39    40  C  铅钡  NaN   风化
# 40    41  C  铅钡   浅绿   风化
# 41    42  A  铅钡   浅蓝   风化
# 42    43  C  铅钡   浅蓝   风化
# 43    44  A  铅钡   浅蓝   风化
# 47    48  A  铅钡  NaN   风化
# 48    49  A  铅钡    黑   风化
# 49    50  A  铅钡    黑   风化
# 50    51  C  铅钡   浅蓝   风化
# 51    52  C  铅钡   浅蓝   风化
# 52    53  A  铅钡   浅蓝   风化
# 53    54  C  铅钡   浅蓝   风化
# 55    56  C  铅钡   蓝绿   风化
# 56    57  C  铅钡   蓝绿   风化
# 57    58  C  铅钡  NaN   风化

# %%
weathering['类型'].value_counts()
# Out:
# 铅钡    28
# 高钾     6
# Name: 类型, dtype: int64

# %%
weathering['纹饰'].value_counts()
# Out:
# C    17
# A    11
# B     6
# Name: 纹饰, dtype: int64

# %%
weathering['颜色'].value_counts()
# Out:
# 浅蓝    12
# 蓝绿     9
# 深绿     4
# 黑      2
# 紫      2
# 浅绿     1
# Name: 颜色, dtype: int64

# %%
no_weathering['类型'].value_counts()
# Out:
# 高钾    12
# 铅钡    12
# Name: 类型, dtype: int64

# %%
no_weathering['纹饰'].value_counts()
# Out:
# C    13
# A    11
# Name: 纹饰, dtype: int64

# %%
no_weathering['颜色'].value_counts()
# Out:
# 浅蓝    8
# 蓝绿    6
# 深绿    3
# 紫     2
# 深蓝    2
# 浅绿    2
# 绿     1
# Name: 颜色, dtype: int64

# %%
import matplotlib.pyplot as plt                #导入绘图包

plt.rcParams['font.sans-serif'] = ['SimHei']   #解决中文显示问题
plt.rcParams['axes.unicode_minus'] = False    # 解决中文显示问题

index = dict(weathering['颜色'].value_counts()).keys()
nums = dict(weathering['颜色'].value_counts()).values()
plt.pie(nums, labels=index,wedgecolor = {'width':0.5},autopct='%3.1f%%')  #以时间为标签，总计成交笔数为数据绘制饼图，并显示3位整数一位小数
plt.title('风化的颜色比例饼图')             #加标题
plt.savefig('img/风化的颜色比例饼图',dpi=300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-32e841bd78ba> in <module>
#       6 index = dict(weathering['颜色'].value_counts()).keys()
#       7 nums = dict(weathering['颜色'].value_counts()).values()
# ----> 8 plt.pie(nums, labels=index,wedgecolor = {'width':0.5})  #以时间为标签，总计成交笔数为数据绘制饼图，并显示3位整数一位小数
#       9 plt.title('风化的颜色比例饼图')             #加标题
#      10 plt.savefig('img/风化的颜色比例饼图',dpi=300)
#
# TypeError: pie() got an unexpected keyword argument 'wedgecolor'

# %%
import matplotlib.pyplot as plt                #导入绘图包

plt.rcParams['font.sans-serif'] = ['SimHei']   #解决中文显示问题
plt.rcParams['axes.unicode_minus'] = False    # 解决中文显示问题

index = dict(no_weathering['颜色'].value_counts()).keys()
nums = dict(no_weathering['颜色'].value_counts()).values()
plt.pie(nums, labels=index, autopct='%3.1f%%')  #以时间为标签，总计成交笔数为数据绘制饼图，并显示3位整数一位小数
plt.title('img/无风化的颜色比例饼图')             #加标题
plt.show()

# %%
import matplotlib.pyplot as plt                #导入绘图包

plt.rcParams['font.sans-serif'] = ['SimHei']   #解决中文显示问题
plt.rcParams['axes.unicode_minus'] = False    # 解决中文显示问题

index = dict(weathering['纹饰'].value_counts()).keys()
nums = dict(weathering['纹饰'].value_counts()).values()
plt.pie(nums, labels=index, autopct='%3.1f%%')  #以时间为标签，总计成交笔数为数据绘制饼图，并显示3位整数一位小数
plt.title('风化的纹饰比例饼图')             #加标题
plt.savefig('img/风化的纹饰比例饼图',dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt                #导入绘图包

plt.rcParams['font.sans-serif'] = ['SimHei']   #解决中文显示问题
plt.rcParams['axes.unicode_minus'] = False    # 解决中文显示问题

index = dict(no_weathering['纹饰'].value_counts()).keys()
nums = dict(no_weathering['纹饰'].value_counts()).values()
plt.pie(nums, labels=index, autopct='%3.1f%%')  #以时间为标签，总计成交笔数为数据绘制饼图，并显示3位整数一位小数
plt.title('img/无风化的纹饰比例饼图')             #加标题
plt.show()

# %%
print(dict(weathering['类型'].value_counts()))
print(dict(no_weathering['类型'].value_counts()))
# Out:
# {'铅钡': 28, '高钾': 6}
# {'铅钡': 12, '高钾': 12}

# %%
#柱状图
import numpy as np
import matplotlib.pyplot as plt
weathering_list = [28,6]
no_weathering_list = [12,12]
x = np.arange(2)

total_width, n = 0.8, 2    # 有多少个类型，只需更改n即可，比如这里我们对比了四个，那么就把n设成4
width = total_width / n
x = x - (total_width - width) / 2
plt.bar(x, weathering_list, color = "r",width=width,label='铅钡')
plt.bar(x + width, no_weathering_list, color = "y",width=width,label='高钾')
plt.xlabel("风化程度")
plt.ylabel("样本数")
plt.legend(loc = "best")
plt.xticks([0,1],['风化','无风化'])
plt.savefig('img/玻璃类型对比柱状图.png')
plt.show()

# %% [markdown]
# ## 1.1 求化学成分的均值

# %%
no_weathering[no_weathering['类型']=='高钾']['文物编号']
# Out:
# 0      1
# 2      3
# 3      4
# 4      5
# 5      6
# 12    13
# 13    14
# 14    15
# 15    16
# 16    17
# 17    18
# 20    21
# Name: 文物编号, dtype: int64

# %%
file1
# Out:
#     文物编号 纹饰  类型   颜色 表面风化
# 0      1  C  高钾   蓝绿  无风化
# 1      2  A  铅钡   浅蓝   风化
# 2      3  A  高钾   蓝绿  无风化
# 3      4  A  高钾   蓝绿  无风化
# 4      5  A  高钾   蓝绿  无风化
# 5      6  A  高钾   蓝绿  无风化
# 6      7  B  高钾   蓝绿   风化
# 7      8  C  铅钡    紫   风化
# 8      9  B  高钾   蓝绿   风化
# 9     10  B  高钾   蓝绿   风化
# 10    11  C  铅钡   浅蓝   风化
# 11    12  B  高钾   蓝绿   风化
# 12    13  C  高钾   浅蓝  无风化
# 13    14  C  高钾   深绿  无风化
# 14    15  C  高钾   浅蓝  无风化
# 15    16  C  高钾   浅蓝  无风化
# 16    17  C  高钾   浅蓝  无风化
# 17    18  A  高钾   深蓝  无风化
# 18    19  A  铅钡  NaN   风化
# 19    20  A  铅钡   浅蓝  无风化
# 20    21  A  高钾   蓝绿  无风化
# 21    22  B  高钾   蓝绿   风化
# 22    23  A  铅钡   蓝绿   风化
# 23    24  C  铅钡    紫  无风化
# 24    25  C  铅钡   浅蓝   风化
# 25    26  C  铅钡    紫   风化
# 26    27  B  高钾   蓝绿   风化
# 27    28  A  铅钡   浅蓝   风化
# 28    29  A  铅钡   浅蓝   风化
# 29    30  A  铅钡   深蓝  无风化
# 30    31  C  铅钡    紫  无风化
# 31    32  C  铅钡   浅绿  无风化
# 32    33  C  铅钡   深绿  无风化
# 33    34  C  铅钡   深绿   风化
# 34    35  C  铅钡   浅绿  无风化
# 35    36  C  铅钡   深绿   风化
# 36    37  C  铅钡   深绿  无风化
# 37    38  C  铅钡   深绿   风化
# 38    39  C  铅钡   深绿   风化
# 39    40  C  铅钡  NaN   风化
# 40    41  C  铅钡   浅绿   风化
# 41    42  A  铅钡   浅蓝   风化
# 42    43  C  铅钡   浅蓝   风化
# 43    44  A  铅钡   浅蓝   风化
# 44    45  A  铅钡   浅蓝  无风化
# 45    46  A  铅钡   浅蓝  无风化
# 46    47  A  铅钡   浅蓝  无风化
# 47    48  A  铅钡  NaN   风化
# 48    49  A  铅钡    黑   风化
# 49    50  A  铅钡    黑   风化
# 50    51  C  铅钡   浅蓝   风化
# 51    52  C  铅钡   浅蓝   风化
# 52    53  A  铅钡   浅蓝   风化
# 53    54  C  铅钡   浅蓝   风化
# 54    55  C  铅钡    绿  无风化
# 55    56  C  铅钡   蓝绿   风化
# 56    57  C  铅钡   蓝绿   风化
# 57    58  C  铅钡  NaN   风化

# %%
from tqdm import tqdm
import re
tqdm.pandas()

def clear_id(s):
    ss = str(s)
    n = int(re.findall(r"\d+",ss)[0])
    return n
file2['id'] = file2['文物采样点'].progress_apply(clear_id)
file1['id'] = file1['文物编号'].progress_apply(clear_id)
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/tqdm/std.py:697: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# 100%|██████████| 69/69 [00:00<00:00, 86909.00it/s]
# 100%|██████████| 58/58 [00:00<00:00, 88590.54it/s]

# %%
file_data = pd.merge(file1,file2,on='id')
weathering_data = file_data[file_data['表面风化']=='风化']
no_weathering_data = file_data[file_data['表面风化']=='无风化']

# %%
Gao_data = weathering_data[weathering_data['类型']=='高钾']
Qian_data = weathering_data[weathering_data['类型']=='铅钡']
no_Gao_data = no_weathering_data[no_weathering_data['类型']=='高钾']
no_Qian_data = no_weathering_data[no_weathering_data['类型']=='铅钡']

# %%
Gao_data.describe()
# Out:
#             文物编号         id  二氧化硅(SiO2)  氧化钠(Na2O)  氧化钾(K2O)  氧化钙(CaO)  \
# count   6.000000   6.000000    6.000000        0.0   4.00000   6.00000
# mean   14.500000  14.500000   93.963333        NaN   0.81500   0.87000
# std     8.068457   8.068457    1.733617        NaN   0.18735   0.48777
# min     7.000000   7.000000   92.350000        NaN   0.59000   0.21000
# 25%     9.250000   9.250000   92.652500        NaN   0.70250   0.64500
# 50%    11.000000  11.000000   93.505000        NaN   0.83000   0.83000
# 75%    19.500000  19.500000   94.837500        NaN   0.94250   1.03750
# max    27.000000  27.000000   96.770000        NaN   1.01000   1.66000
#
#        氧化镁(MgO)  氧化铝(Al2O3)  氧化铁(Fe2O3)  氧化铜(CuO)  氧化铅(PbO)  氧化钡(BaO)  \
# count  2.000000     6.00000    6.000000  6.000000       0.0       0.0
# mean   0.590000     1.93000    0.265000  1.561667       NaN       NaN
# std    0.070711     0.96449    0.069498  0.934824       NaN       NaN
# min    0.540000     0.81000    0.170000  0.550000       NaN       NaN
# 25%    0.565000     1.35500    0.215000  1.015000       NaN       NaN
# 50%    0.590000     1.72000    0.275000  1.545000       NaN       NaN
# 75%    0.615000     2.37750    0.312500  1.625000       NaN       NaN
# max    0.640000     3.50000    0.350000  3.240000       NaN       NaN
#
#        五氧化二磷(P2O5)  氧化锶(SrO)  氧化锡(SnO2)  二氧化硫(SO2)
# count     5.000000       0.0        0.0        0.0
# mean      0.336000       NaN        NaN        NaN
# std       0.177708       NaN        NaN        NaN
# min       0.150000       NaN        NaN        NaN
# 25%       0.210000       NaN        NaN        NaN
# 50%       0.350000       NaN        NaN        NaN
# 75%       0.360000       NaN        NaN        NaN
# max       0.610000       NaN        NaN        NaN

# %%
Qian_data.describe()
# Out:
#             文物编号         id  二氧化硅(SiO2)  氧化钠(Na2O)   氧化钾(K2O)   氧化钙(CaO)  \
# count  36.000000  36.000000   36.000000  11.000000  16.000000  34.000000
# mean   38.305556  38.305556   33.614722   3.117273   0.321250   2.483529
# std    15.291117  15.291117   17.221484   2.340812   0.215434   1.549690
# min     2.000000   2.000000    3.720000   0.800000   0.110000   0.370000
# 25%    27.500000  27.500000   21.047500   1.300000   0.207500   1.235000
# 50%    42.000000  42.000000   29.395000   2.310000   0.300000   2.305000
# 75%    50.250000  50.250000   50.772500   4.370000   0.342500   3.190000
# max    58.000000  58.000000   68.080000   7.920000   1.050000   6.400000
#
#         氧化镁(MgO)  氧化铝(Al2O3)  氧化铁(Fe2O3)   氧化铜(CuO)   氧化铅(PbO)   氧化钡(BaO)  \
# count  23.000000   36.000000   21.000000  34.000000  36.000000  33.000000
# mean    1.096957    3.838333    0.952857   2.113529  36.871944  11.440606
# std     0.480250    3.412626    0.663853   2.511852  15.163722   8.646204
# min     0.470000    0.450000    0.190000   0.190000  12.310000   2.030000
# 25%     0.750000    1.615000    0.410000   0.700000  24.797500   6.650000
# 50%     1.110000    3.010000    0.810000   1.125000  39.795000   8.940000
# 75%     1.240000    4.837500    1.330000   2.922500  46.767500  11.860000
# max     2.730000   14.340000    2.740000  10.570000  70.210000  35.450000
#
#        五氧化二磷(P2O5)   氧化锶(SrO)  氧化锡(SnO2)  二氧化硫(SO2)
# count    30.000000  32.000000   3.000000   4.000000
# mean      4.986333   0.412188   0.670000   8.880000
# std       4.062661   0.220069   0.567098   7.645997
# min       0.070000   0.120000   0.230000   1.960000
# 25%       1.115000   0.247500   0.350000   2.425000
# 50%       4.280000   0.370000   0.470000   8.805000
# 75%       7.965000   0.485000   0.890000  15.260000
# max      14.130000   1.120000   1.310000  15.950000

# %%
mean_df = pd.DataFrame(columns=['风化高钾的元素均值','无风化高钾的元素均值','风化铅钡的元素均值','无风化铅钡的元素均值'])
mean_df['风化高钾的元素均值'] = list(Gao_data.describe().iloc[1])[2:]
mean_df['无风化高钾的元素均值'] = list(no_Gao_data.describe().iloc[1])[2:]
mean_df['风化铅钡的元素均值'] = list(Qian_data.describe().iloc[1])[2:]
mean_df['无风化铅钡的元素均值'] = list(no_Qian_data.describe().iloc[1])[2:]

# %%
mean_df.index = list(Gao_data.describe().columns)[2:]

# %%
# 0值填充缺失值
mean_df = mean_df.fillna(0)
mean_df['高钾风化前后差值'] = mean_df['风化高钾的元素均值']-mean_df['无风化高钾的元素均值']
mean_df['铅钡风化前后差值'] = mean_df['风化铅钡的元素均值']-mean_df['无风化铅钡的元素均值']
mean_df
# Out:
#              风化高钾的元素均值  无风化高钾的元素均值  风化铅钡的元素均值  无风化铅钡的元素均值   高钾风化前后差值  \
# 二氧化硅(SiO2)   93.963333   67.027857  33.614722   53.443846  26.935476
# 氧化钠(Na2O)     0.000000    2.734000   3.117273    3.343333  -2.734000
# 氧化钾(K2O)      0.815000    9.624615   0.321250    0.420000  -8.809615
# 氧化钙(CaO)      0.870000    6.399000   2.483529    1.455455  -5.529000
# 氧化镁(MgO)      0.590000    1.235000   1.096957    0.914286  -0.645000
# 氧化铝(Al2O3)    1.930000    6.353077   3.838333    3.194615  -4.423077
# 氧化铁(Fe2O3)    0.265000    2.105000   0.952857    2.021667  -1.840000
# 氧化铜(CuO)      1.561667    2.446923   2.113529    1.840000  -0.885256
# 氧化铅(PbO)      0.000000    0.591111  36.871944   23.593846  -0.591111
# 氧化钡(BaO)      0.000000    1.025714  11.440606   10.499231  -1.025714
# 五氧化二磷(P2O5)   0.336000    1.328462   4.986333    1.068182  -0.992462
# 氧化锶(SrO)      0.000000    0.083333   0.412188    0.482500  -0.083333
# 氧化锡(SnO2)     0.000000    1.180000   0.670000    0.420000  -1.180000
# 二氧化硫(SO2)     0.000000    0.406667   8.880000    3.660000  -0.406667
#
#               铅钡风化前后差值
# 二氧化硅(SiO2)  -19.829124
# 氧化钠(Na2O)    -0.226061
# 氧化钾(K2O)     -0.098750
# 氧化钙(CaO)      1.028075
# 氧化镁(MgO)      0.182671
# 氧化铝(Al2O3)    0.643718
# 氧化铁(Fe2O3)   -1.068810
# 氧化铜(CuO)      0.273529
# 氧化铅(PbO)     13.278098
# 氧化钡(BaO)      0.941375
# 五氧化二磷(P2O5)   3.918152
# 氧化锶(SrO)     -0.070312
# 氧化锡(SnO2)     0.250000
# 二氧化硫(SO2)     5.220000

# %%
mean_df.to_csv('data/风化前后高钾和铅钡的均值对比表.csv')

# %%
#柱状图
import numpy as np
import matplotlib.pyplot as plt
f_list = mean_df['风化高钾的元素均值'][1:]
s_list = mean_df['无风化高钾的元素均值'][1:]
n = len(f_list)
x = np.arange(n)

total_width= 0.8    # 有多少个类型，只需更改n即可，比如这里我们对比了四个，那么就把n设成4
width = total_width / n
x = x - (total_width - width) / 2
plt.bar(x, f_list, color = "r",width=width,label='风化')
plt.bar(x + width, s_list, color = "y",width=width,label='无风化')
plt.xlabel("化学成分")
plt.ylabel("数值")
plt.legend(loc = "best")
plt.xticks(range(n),mean_df.index[1:])
plt.savefig('img/风化前后元素对比柱状图.png')
plt.show()
